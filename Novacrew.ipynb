# %% [markdown]
# <a href="https://colab.research.google.com/github/azrilsonda/Gabriel-xrpl-/blob/main/Novacrew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Menghitung keliling persegi panjang
#
# Nama kelompok nov:
# 1.azril
# 2.iky
# 3.dapa
# 4.rapa
# 5.afra
# 6.delianra

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile kelilingpersegipanjang.cpp
# #include <iostream>
# using namespace std;
# int main ()
# {
# int p,l,keliling;
#  cout<<"masukan panjang"<<endl;
#  cin>>p;
#  cout<<"masukan lebar"<<endl;
#  cin>>l;
#  keliling=2*p+l;
#  cout<<"keliling persegi panjang adalah "<<keliling<<endl;
# return 0;
# }
# Out:
# Overwriting kelilingpersegipanjang.cpp

# %%
# !g++ kelilingpersegipanjang.cpp -o main

# %%
! ./main
# Out:
# masukan panjang
# 59
# masukan lebar
